# %%
import pandas as pd

# %%
df = pd.read_csv("iris.csv")

# %%
df.head(2)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa

# %%
df = df.drop("Id",axis =1)

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.dtypes
# Out:
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
unique = len(df['Species'].unique())

# %%
unique
# Out:
# 3

# %%
mapping = {'Iris-virginica':0,"Iris-setosa":1,"Iris-versicolor":2}

# %%
df['Species'] = df['Species'].map(mapping)

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0              5.1           3.5            1.4           0.2        1
# 1              4.9           3.0            1.4           0.2        1
# 2              4.7           3.2            1.3           0.2        1
# 3              4.6           3.1            1.5           0.2        1
# 4              5.0           3.6            1.4           0.2        1
# ..             ...           ...            ...           ...      ...
# 145            6.7           3.0            5.2           2.3        0
# 146            6.3           2.5            5.0           1.9        0
# 147            6.5           3.0            5.2           2.0        0
# 148            6.2           3.4            5.4           2.3        0
# 149            5.9           3.0            5.1           1.8        0
#
# [150 rows x 5 columns]

# %%
df['Species'].value_counts()
# Out:
# Species
# 1    50
# 2    50
# 0    50
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df1 = df.corr()
df1
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000
# Species            -0.322522     -0.192719      -0.299942     -0.375715
#
#                 Species
# SepalLengthCm -0.322522
# SepalWidthCm  -0.192719
# PetalLengthCm -0.299942
# PetalWidthCm  -0.375715
# Species        1.000000

# %%
sns.pairplot(df,hue='Species',palette='Oranges_r')
# Out:
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.heatmap(df1,annot=True)
# Out:
# <Axes: >

# %%
sns.scatterplot(x='SepalWidthCm',y='Species',data=df)
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='Species'>

# %%
sns.scatterplot(x='SepalLengthCm',y='PetalLengthCm',data=df)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
sns.scatterplot(x='SepalLengthCm',y='PetalWidthCm',data=df)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalWidthCm'>

# %%
X = df.drop("Species",axis=1)

# %%
y = df["Species"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.4, random_state=3)

# %%
from sklearn.preprocessing import StandardScaler

# %%
Scaler = StandardScaler()

# %%
Scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train_Scaled = Scaler.transform(X_train)

# %%
X_test_Scaled = Scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
knn = KNeighborsClassifier()
svm = SVC()
gb = GaussianNB()
dt = DecisionTreeClassifier()
rf = RandomForestClassifier()

# %%
rf.fit(X_train, y_train)
print("accuracy of random forest: ",rf.score(X_test,y_test))
y_pred=rf.predict(X_test)
y_true=y_test
# Out:
# accuracy of random forest:  0.95

# %%
knn.fit(X_train, y_train)
print("accuracy of knn: ",knn.score(X_test,y_test))
y_pred=knn.predict(X_test)
y_true=y_test
# Out:
# accuracy of knn:  0.9333333333333333

# %%
svm.fit(X_train, y_train)
print("accuracy of svm: ",svm.score(X_test,y_test))
y_pred=svm.predict(X_test)
y_true=y_test
# Out:
# accuracy of svm:  0.95

# %%
model = gb.fit(X_train, y_train)
print("accuracy of gb: ",gb.score(X_test,y_test))
y_pred=gb.predict(X_test)
# Out:
# accuracy of gb:  0.9833333333333333

# %%
dt.fit(X_train, y_train)
print("accuracy of decision tree: ",dt.score(X_test,y_test))
y_pred=dt.predict(X_test)
y_true=y_test
# Out:
# accuracy of decision tree:  0.95

# %%
import numpy as np
def prediction_Species(SepalLengthCm,SepalWidthCm,PetalLengthCm,PetalWidthCm):
    features = np.array(([SepalLengthCm,SepalWidthCm,PetalLengthCm,PetalWidthCm]))
    reshaped = features.reshape(1,-1)
    pred = gb.predict(reshaped)
    return  pred[0]

SepalLengthCm =1.5 
SepalWidthCm = 2.0
PetalLengthCm = 3.5
PetalWidthCm = 1.6

prediction = prediction_Species(SepalLengthCm,SepalWidthCm,PetalLengthCm,PetalWidthCm)
# Out:
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(

# %%
prediction
# Out:
# 0

# %%
import joblib
import numpy as np
joblib.dump(model,'model_saved2')
# Out:
# ['model_saved2']

# %%
load_model=joblib.load("model_saved2")
load_model
# Out:
# GaussianNB()

# %%
prediction_Species(3.2,5.4,6.5,7.8)
# Out:
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# 0
